# %% [markdown]
# ### Initial look at clustering for Asteroid tracklets:

# %% [markdown]
# Asteroid tracklets CS 182 project: Paul Blankley, Ryan Janssen, Matthew Holman
#
# Potentially useful docs / sources:
#
# Blog: https://joernhees.de/blog/2015/08/26/scipy-hierarchical-clustering-and-dendrogram-tutorial/#Inconsistency-Method
#
# Cophenet: https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.cluster.hierarchy.cophenet.html
#
# Linkage: https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.linkage.html#scipy.cluster.hierarchy.linkage
#
# Inconsistent: https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.inconsistent.html
#
# Fcluster: https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.fcluster.html

# %%
# Imports
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.cluster.hierarchy import inconsistent
from scipy.cluster.hierarchy import fcluster
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist
import numpy as np
from collections import defaultdict

# %matplotlib inline

# %%
with open('../ITF/test_r2.5_rd0.out','r') as file:
    lines = file.read().split('\n')
    r2p5 = [i.split() for i in lines[:-1]]
    mxs = [float(i[1]) for i in r2p5]
    cxs = [float(i[2]) for i in r2p5]
    mys = [float(i[3]) for i in r2p5]
    cys = [float(i[4]) for i in r2p5]

# %%
# Basic Asteroid vector plot
# fig=plt.figure(figsize=(18, 16))
# plt.quiver(cxs, cys, mxs, mys, scale=0.2, width=0.0005)
# plt.xlim(-0.0, 0.3)
# plt.ylim(-0.2, 0.1)
# plt.xlabel('alpha')
# plt.ylabel('beta')
# plt.title('Asteroids')

# %% [markdown]
# The below dendrogram shows the higher level clustering of the hierarchical model.  For a good tutorial and more reading on this type of clustering check this out: https://joernhees.de/blog/2015/08/26/scipy-hierarchical-clustering-and-dendrogram-tutorial/
#
# NOTE: This is the high level clustering, we are interested in the low level where the tracklets are very close to each other.

# %%
# Convert the array to a numpy array
numeric_vals = np.array([mxs, cxs, mys, cys]).T

# Make linkage
Z = linkage(numeric_vals, 'ward')

# Dendogram
fig,ax = plt.subplots(figsize=(16,12))
plt.title('Hierarchical Clustering Dendrogram (truncated)')
plt.xlabel('Cluster size)')
plt.ylabel('Distance (euclidean - Ward Link)')
dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=55,  # show only the last p merged clusters
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.show()

# %% [markdown]
# The correlation coefficient below compares the accuracy of the dendrogram distance (the link height) with the actual pairwise distances in the original matrix to see how well the dendrogram preserves pairwise distance.  The closer the number is to 1.0 the better. Check out this link for further reading: https://en.wikipedia.org/wiki/Cophenetic_correlation
#
# The Cophenetic distance is the measure the `i_cutp` variable represents in the fcluster clustering method under many paradigms, but *not* inconsistent.  If a cluster node and all its descendants have an inconsistent value less than or equal to $t$ (our `i_cutp`) then all its leaf descendants belong to the same cluster. When no non-singleton cluster meets this criterion, every node is assigned to its own cluster.

# %%
# Cluster with a max d
max_d = 0.00005
clusters_md = fcluster(Z, max_d, criterion='distance')

# Cluster using inconsistency metric
# Objects between clusters have no greater distance than the dist_bet value below 
i_cutp = .9
incon = inconsistent(Z,20)
clusters_i = fcluster(Z, i_cutp, criterion='inconsistent', depth=10)

c_cor, coph_dists = cophenet(Z,pdist(numeric_vals))
print('Cophenetic correlation coefficient:',c_cor)
print('Avg Cophenetic distance:',coph_dists.mean())
sns.distplot(coph_dists,kde=False)
plt.title('The frequency distribution of Cophenet distances.')
plt.xlabel('Distance')
plt.ylabel('Frequency')
# Out:
# Cophenetic correlation coefficient: 0.854568379056
# Avg Cophenetic distance: 2.02351879883

# %% [markdown]
# Here are the goods (kind of).  This plot shows the clustering by color and I think we can see some pretty good behavior initially from the clusters.  They look pretty tight and seem to be seperating the data in a meaningful way.  This can be significantly improved by dropping some less useful clusters and by tuning the hyperparameters to optimally cluster the vectors.  I will discuss the hyperparameters in detail later.

# %%
fig=plt.figure(figsize=(18, 16))
plt.quiver(cxs, cys, mxs, mys, clusters_i, cmap='prism',scale=0.2, width=0.0005)
plt.xlim(-0.0, 0.3)
plt.ylim(-0.2, 0.1)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.title('Clustered Asteroids')

# %%
# Plots of distributions of the inconsistency clusters
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(16,8))
sns.distplot(incon[:,0],ax=ax1)
ax1.set_title('distribution of means')

# sns.distplot(np.log(incon[:,0]),ax=ax2)
# ax2.set_title('log distribution of means')

sns.distplot(incon[:,3],ax=ax2)
ax2.set_title('distribution of inconsistency metrics (standardized linkage)')

# sns.distplot(incon[:,2],ax=ax4)
# ax4.set_title('distribution of the number of links in the calculation')

# %% [markdown]
# Inconsistency is the first unsupervised method we decided to apply to this problem.  Inconsistency has two hyperparameters.  The first is the `depth` value.  This value tells the algorithm what depth to stop searching as it goes up the tree.  The next is the `threshold` (our `i_cut` variable) value which we use to specify the inconsistency value above which we will not cluster any points, and below which we say the elements we clustered belong in a cluster together.
#
# NOTES:
#
# Objects between clusters have no greater distance than the `dist_bet` value below.
#
# Value, that is `clusters_i[j]`, in `clusters_i` is the key of the cluster the point j belongs to, whereas the output from inconsistent at `incon[j]` relates to the jth *cluster* not the jth point in the original data. Thus, the index of `incon` is directly related to the value of `clusters_i`.

# %%
# Arb set cutpoint based on the inconsistency metric 
cutoff = .5

########################################################

# Cluster with a max d
#max_d = 0.05
#clusters_md = fcluster(Z, max_d, criterion='distance')

# Cluster using inconsistency metric 
dist_bet = .0000008  # seems to control the proximity of vectors we allow to cluster
incon = inconsistent(Z,20)
clusters_i = fcluster(Z, dist_bet, criterion='inconsistent', depth=2)
print(max(clusters_i))

# Drop clusters that don't meet a certain cutoff for the inconsistency metric (col 4 of the incon output)
sns.distplot(incon[:,3])
plt.title('Distribution of the inconsistency metric.')
plt.show()

for i in range(len(incon)):
    t = incon[i,3]>cutoff
    if t:
        if i in clusters_i:
            for j,itm in enumerate(clusters_i):
                if itm==i:
                    clusters_i[j] = 1

# Asteroid plot
fig=plt.figure(figsize=(18, 16))
plt.quiver(cxs, cys, mxs, mys, clusters_i, cmap='prism',scale=0.2, width=0.0005)
plt.xlim(-0.0, 0.3)
plt.ylim(-0.2, 0.1)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.title('Asteroids 2.0')
# Out:
# 646

# %% [markdown]
# Now we can assign the labels to the clusters.  We know the output of the `fcluster` method is going to be in order of the original data so this is a valid assignment.
#
# Docs: https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.fcluster.html

# %%
# Create the labels vector
labels = [i[0] for i in r2p5]

# Create a dict with the cluster id as the key and the associated tracklet id's as the values
clusters_with_tags = defaultdict(list)
for i, itm in enumerate(clusters_md):
    clusters_with_tags[itm].append(labels[i])


num_obs_in_clusters = [len(val) for k, val in clusters_with_tags.items() if k !=1]

print('We found {} different clusters of tracklets.'.format(len(clusters_with_tags.keys())-1))
print('The average cluster size is {0:.3f}'.format(np.mean(num_obs_in_clusters)))
print('We clustered {} tracklet ids.'.format(np.sum(num_obs_in_clusters)))
print('Largest cluster:',max(num_obs_in_clusters))
# Out:
# We found 431 different clusters of tracklets.
# The average cluster size is 2.385
# We clustered 1028 tracklet ids.
# Largest cluster: 67

# %%
clusters_with_tags[1]=[None]
clusters_with_tags
# Out:
# defaultdict(list,
#             {1: [None],
#              2: ['P10CWVj'],
#              3: ['YQA70E2', 'A103Hgs'],
#              4: ['YQA70E3', 'YQA75D1'],
#              5: ['YQA70E4'],
#              6: ['YQA70D5'],
#              7: ['X51521'],
#              8: ['YQA714D'],
#              9: ['P10CWVE'],
#              10: ['P10DHos', 'P10CWzA'],
#              11: ['P10CvKG', 'P10CqPu'],
#              12: ['P10CqRp'],
#              13: ['P10CvKa'],
#              14: ['P10CvKw'],
#              15: ['P10CvKp'],
#              16: ['P10DHoe'],
#              17: ['P10DftC'],
#              18: ['P10Dfs4'],
#              19: ['P10CWCm'],
#              20: ['P10DfuO'],
#              21: ['P10CWBB'],
#              22: ['RvQ51F'],
#              23: ['P10CWBz'],
#              24: ['P10DfwF'],
#              25: ['YSAE24A'],
#              26: ['A103AWw'],
#              27: ['P10CvKm'],
#              28: ['A103J3Z'],
#              29: ['YSAE24B'],
#              30: ['P10DHpi'],
#              31: ['P10DHpv'],
#              32: ['YQA766C', 'P10CvKl'],
#              33: ['P10CWCa'],
#              34: ['P10DHoV'],
#              35: ['P10CvJA', 'YQA75F1'],
#              36: ['P10CWVJ'],
#              37: ['YQA75BD'],
#              38: ['P10Do74', 'YSAC409'],
#              39: ['P10CWV4'],
#              40: ['P10CqQ8'],
#              41: ['YQA7114'],
#              42: ['YQA7157', 'YQA7159'],
#              43: ['YQA70F4'],
#              44: ['YQA70FB'],
#              45: ['YQA7107'],
#              46: ['YQA7631'],
#              47: ['YQA762D'],
#              48: ['YQA7CE4', 'YQA7D05'],
#              49: ['YQA7CE7'],
#              50: ['P10CqPE', 'P10CvJm'],
#              51: ['P10CvKh', 'P10CvKv'],
#              52: ['RuTC02', 'YQA7619', 'P10CvJG'],
#              53: ['P10CvJT', 'YQA769C'],
#              54: ['P10CvKK'],
#              55: ['YQA760F'],
#              56: ['P10CvJJ'],
#              57: ['P10CvKc'],
#              58: ['P10CqTF', 'P10CqUq', 'P10CqSd'],
#              59: ['P10CqTR'],
#              60: ['X51324', 'P10CqRV', 'P10CqST'],
#              61: ['P10CqTV'],
#              62: ['P10CqSt'],
#              63: ['P10DN4L'],
#              64: ['P10DHoz'],
#              65: ['P10DHqR'],
#              66: ['P10DHoS', 'P10DHp1', 'P10DHp7', 'P10DHoo'],
#              67: ['P10DHok'],
#              68: ['P10DN4O'],
#              69: ['P10DHoL'],
#              70: ['P10CWVu', 'P10CWV3'],
#              71: ['YQA75C7'],
#              72: ['P10CWV6'],
#              73: ['YQA70F5', 'P10CWUZ'],
#              74: ['P10CWV5', 'YQA7600'],
#              75: ['P10CWVG'],
#              76: ['P10CWVs', 'YQA75FB'],
#              77: ['P10CvJi'],
#              78: ['RuJA02'],
#              79: ['YQA75CB', 'P10CWVz'],
#              80: ['P10CWVk'],
#              81: ['YQA75D0'],
#              82: ['P10CWV2'],
#              83: ['P10CWUU'],
#              84: ['P10CWVF'],
#              85: ['YQA75BB'],
#              86: ['P10CWUS', 'YQA75BA', 'YQA75C6', 'P10CWVt'],
#              87: ['P10CWVK', 'YQA75B9', 'YQA75FD'],
#              88: ['P10CWVw'],
#              89: ['P10CvJj'],
#              90: ['YQA7601'],
#              91: ['P10CvJN'],
#              92: ['YSB0AD2'],
#              93: ['P10CvKu'],
#              94: ['P10CvKQ'],
#              95: ['P10CvLS'],
#              96: ['YQA7C2E'],
#              97: ['YQA7C3B'],
#              98: ['Groesu', 'P10CqRs', 'P10CqS1'],
#              99: ['P10DHpf', 'P10CWBy', 'P10DN4G'],
#              100: ['P10DHou'],
#              101: ['P10DHoH'],
#              102: ['P10DHqD'],
#              103: ['P10DHox'],
#              104: ['P10DHoG'],
#              105: ['P10CWAa', 'P10DHp0'],
#              106: ['P10DN4W'],
#              107: ['P10CWCc'],
#              108: ['P10DHqT'],
#              109: ['YQA7614', 'YSAE26B'],
#              110: ['P10Ds4t'],
#              111: ['YQA7158', 'YQA7123'],
#              112: ['YQA7155'],
#              113: ['P10CvLe'],
#              114: ['P10CvKH'],
#              115: ['RuHK03', 'RuH102', 'RuTE05', 'YQA7694'],
#              116: ['P10CvJU'],
#              117: ['YQA761B'],
#              118: ['YQA762C'],
#              119: ['YQA7CEA'],
#              120: ['P10DN5G'],
#              121: ['P10DHqy'],
#              122: ['P10DN4N'],
#              123: ['P10DHq4'],
#              124: ['P10DHqi'],
#              125: ['P10CWBx'],
#              126: ['P10CWB0'],
#              127: ['YQA710A'],
#              128: ['P10CWVx'],
#              129: ['YQA714B'],
#              130: ['YQA75F0'],
#              131: ['P10CvJB'],
#              132: ['P10CvKr', 'P10CqQ6'],
#              133: ['P10CvJD', 'YQA70FC', 'YQA714A', 'P10CWVm'],
#              134: ['YQA70F2', 'P10CWUX'],
#              135: ['P10CvJt', 'P10CvLa', 'YQA75F5', 'P10CvKn', 'YQA75F3'],
#              136: ['YQA75F4'],
#              137: ['P10CvJy'],
#              138: ['YQA714C'],
#              139: ['YQA7CD0'],
#              140: ['YQA7CD4'],
#              141: ['P10CvLx'],
#              142: ['P10CvLw'],
#              143: ['YQA713E', 'YQA7124'],
#              144: ['YQA7140'],
#              145: ['P10CqSN'],
#              146: ['YQA7141'],
#              147: ['YQA7115'],
#              148: ['YQA713F'],
#              149: ['P10DN53', 'P10DHpb'],
#              150: ['P10CWBe'],
#              151: ['A103rPu', 'P10CqVl'],
#              152: ['X51473', 'A103y5K'],
#              153: ['P10CqRM'],
#              154: ['P10CqUI', 'P10CqVc'],
#              155: ['P10CqRt'],
#              156: ['P10CqVx'],
#              157: ['P10CvMK', 'P10DHqM'],
#              158: ['P10CvLh', 'P10DHpc', 'P10CvMM'],
#              159: ['P10DHoJ'],
#              160: ['P10CqS4', 'YQA7122'],
#              161: ['P10CqQa'],
#              162: ['RuTE06', 'P10CvLk'],
#              163: ['P10CqSc', 'P10CqTI'],
#              164: ['P10CqS7', 'P10CqSw', 'P10CqTP'],
#              165: ['P10CqTX'],
#              166: ['P10CqUT'],
#              167: ['P10CqS9'],
#              168: ['P10CqSY', 'P10CqUJ', 'P10CqTn', 'P10CqSn'],
#              169: ['P10CqRA'],
#              170: ['P10CqVz'],
#              171: ['P10CqUK'],
#              172: ['P10CqUy', 'P10CqSx'],
#              173: ['P10CqVg'],
#              174: ['P10CqS8'],
#              175: ['P10CvKq', 'YRA8A4D', 'YQA767D'],
#              176: ['P10DHq2', 'P10DHpY'],
#              177: ['P10DHq5', 'P10CWBF'],
#              178: ['P10DN5B', 'P10DHqr', 'P10CWBf', 'P10DN5f'],
#              179: ['P10CWBA', 'P10CWzT'],
#              180: ['P10DHpB', 'P10CWBG'],
#              181: ['P10DN4C'],
#              182: ['P10CvKo'],
#              183: ['P10CqVP', 'P10CqSu'],
#              184: ['P10DHpT', 'P10DHoQ'],
#              185: ['P10DHp8'],
#              186: ['P10DHor'],
#              187: ['A103viE', 'P10CqRv'],
#              188: ['P10CvO2', 'P10CqVw'],
#              189: ['P10CvLz', 'RuHI01'],
#              190: ['P10CqSi', 'P10CqTE'],
#              191: ['p10cvjf',
#               'P10CqT1',
#               'P10CqTw',
#               'P10CqRU',
#               'P10CqRw',
#               'P10CqVC',
#               'P10CqRE'],
#              192: ['P10CqRO'],
#              193: ['P10DN58', 'P10DHp3'],
#              194: ['P10CvNT'],
#              195: ['P10CqRN',
#               'YQA7125',
#               'A103y5L',
#               'YQA7142',
#               'P10CqSK',
#               'P10CqSA',
#               'A103Hgz'],
#              196: ['P10CvMI',
#               'P10CqTx',
#               'P10CqRy',
#               'P10CqTW',
#               'P10CvM1',
#               'P10CqPL',
#               'P10CqRq',
#               'YQA7CE8',
#               'P10CvJu',
#               'YQA7CE5',
#               'YQA7CE1',
#               'YQA7CFD',
#               'P10CqSl',
#               'YQA7CEC',
#               'P10CqSB',
#               'YQA7CE2',
#               'YQA7CE9',
#               'YQA7CE3'],
#              197: ['YQA7156'],
#              198: ['P10CqSa'],
#              199: ['P10CqTj'],
#              200: ['P10CqUP'],
#              201: ['P10CqTC'],
#              202: ['P10CqRF'],
#              203: ['P10CqRB', 'P10CqSp'],
#              204: ['P10CqUr'],
#              205: ['YQA7121', 'P10CqTe', 'P10CqTp', 'P10CqSL', 'P10CqTr'],
#              206: ['P10CqSX', 'P10CqSZ'],
#              207: ['P10CqTs', 'P10CqSv'],
#              208: ['YQA7D08'],
#              209: ['P10CqPx'],
#              210: ['P10CvLc', 'P10CvLD'],
#              211: ['YQA7C2F'],
#              212: ['P10DN4T', 'P10DHqk'],
#              213: ['RuTE08', 'P10CvN5'],
#              214: ['P10CvMs'],
#              215: ['P10CvKX', 'P10CvMe'],
#              216: ['P10CvML'],
#              217: ['P10CqTG', 'P10CqSG', 'P10CvN3', 'X51546', 'P10CvLZ'],
#              218: ['P10DN5H'],
#              219: ['P10DHpt'],
#              220: ['P10CWBC', 'P10DN5Q', 'P10DN57', 'P10DHpN'],
#              221: ['P10DN5k'],
#              222: ['P10CvN4', 'P10CvMR'],
#              223: ['P10CqPy', 'YQA7DB0'],
#              224: ['P10CqSP'],
#              225: ['P10DHqL',
#               'P10DN5V',
#               'P10CWBr',
#               'P10DHp6',
#               'P10DN5w',
#               'P10DHqH',
#               'P10DN5m'],
#              226: ['P10CvNp', 'P10CJqv'],
#              227: ['P10CLkp', 'P10CJfA'],
#              228: ['P10CqU0', 'P10CLlv', 'P10CJgs', 'P10CLl5'],
#              229: ['P10CvMN', 'P10CqTY', 'P10CJqp', 'P10CJxL'],
#              230: ['P10CqU5', 'P10CJmF', 'P10CLsJ', 'P10CJrV'],
#              231: ['P10CvJS', 'P10CJfH', 'P10CJr4'],
#              232: ['P10DN4F', 'YQA7689', 'P10DHot'],
#              233: ['P10CvNL', 'P10DHqS'],
#              234: ['P10CvLR', 'P10DHpL'],
#              235: ['P10DHpu'],
#              236: ['P10DHqv', 'P10DHoE'],
#              237: ['P10CWAH', 'P10DHpV'],
#              238: ['P10CWBs',
#               'P10DN5I',
#               'P10DHpz',
#               'P10DHpZ',
#               'P10CWBw',
#               'P10CWBi',
#               'P10DN5x'],
#              239: ['P10DN5L',
#               'P10DN5C',
#               'P10DHpQ',
#               'P10DN4S',
#               'P10DHpx',
#               'P10CWBc',
#               'P10DHpK'],
#              240: ['P10DN5N'],
#              241: ['P10DHpR', 'P10CWLE', 'P10DHpO', 'P10DHoh', 'P10DN5E'],
#              242: ['P10DHpq'],
#              243: ['gMO8002'],
#              244: ['P10CWB8', 'P10DHqx'],
#              245: ['P10DHqm'],
#              246: ['P10DHpC', 'P10DN55', 'P10DHpE'],
#              247: ['P10DHow'],
#              248: ['YS1B189', 'P10DN5S'],
#              249: ['P10DN5K',
#               'P10CWBl',
#               'P10DN5J',
#               'P10DHpa',
#               'P10DHpg',
#               'P10DN5r',
#               'P10DHoP',
#               'P10DHpm'],
#              250: ['P10DN5j', 'P10DHph', 'P10DN4X'],
#              251: ['P10DHqP',
#               'YSB39E9',
#               'P10DN5p',
#               'P10CWBD',
#               'P10CWLD',
#               'P10DHq3'],
#              252: ['P10CWAI', 'P10DN5z'],
#              253: ['P10DHq6'],
#              254: ['P10DHoX'],
#              255: ['A103H1M'],
#              256: ['RuJA06'],
#              257: ['RuU108', 'P10CvJz', 'RuTD0C'],
#              258: ['P10CvNP', 'P10CvNN'],
#              259: ['P10CvNU', 'P10CvNY'],
#              260: ['P10CvN0', 'YQA7C78', 'P10CvNV', 'YQA7C3F', 'P10CvMj'],
#              261: ['YQA7C5A'],
#              262: ['P10DN4Q', 'P10DHov', 'P10DN52', 'P10CWB3', 'P10DN5h'],
#              263: ['P10DN5v'],
#              264: ['P10CvL9', 'YQA7CD1'],
#              265: ['P10CqTm', 'P10CvM4'],
#              266: ['P10CvLX',
#               'YQA7C5F',
#               'P10CvMq',
#               'P10CJbU',
#               'P10CqUm',
#               'P10CqT9',
#               'P10CvMg',
#               'P10CvMU'],
#              267: ['P10CJjH',
#               'YQA7D9B',
#               'P10CvMS',
#               'YQA7DAD',
#               'P10CvO5',
#               'YQA7CDF',
#               'YQA7DAC',
#               'P10CvNM',
#               'P10CvLt',
#               'YQA7CE0',
#               'P10CqSz',
#               'P10CvKT',
#               'P10CvNX',
#               'P10CvNd',
#               'P10CvNO',
#               'P10CvM7',
#               'P10CvNH',
#               'P10CvLK',
#               'P10CvNg',
#               'P10CvNI',
#               'P10CvMH',
#               'P10CJsR',
#               'P10CJuu',
#               'P10CvMA',
#               'YQA7DAE',
#               'YQA7D9D',
#               'P10CqUd',
#               'YQA7D9E',
#               'P10CLnR',
#               'P10CqVa',
#               'P10CvNn',
#               'YQA7CC9',
#               'P10CJhb'],
#              268: ['P10CvJF',
#               'YQA7CD3',
#               'P10CvMV',
#               'P10CqVe',
#               'YQA7CC7',
#               'P10CvMG',
#               'P10CvNr',
#               'P10CvMy',
#               'P10CvMF',
#               'P10CvNx',
#               'YQA7CD2',
#               'P10CvNm',
#               'P10CvKS',
#               'P10CvL1',
#               'YQA7C42',
#               'P10CqSe',
#               'P10CqSS',
#               'P10CvJK',
#               'P10CvLA',
#               'YQA7CE6',
#               'YQA7CC8',
#               'YQA7CB7',
#               'P10CvO0',
#               'P10CvM5',
#               'YQA7DAF',
#               'P10CvK7',
#               'P10CvNq',
#               'P10CvKP',
#               'P10CJf7',
#               'YQA7CB8',
#               'YQA7CD5',
#               'P10CvKR',
#               'P10CvMn',
#               'YQA7DAB',
#               'P10CvMl',
#               'P10CvMd',
#               'P10CvMx',
#               'P10CqRW'],
#              269: ['P10DHqp', 'P10DN4Z', 'P10DN4y', 'P10DHq8'],
#              270: ['P10DN5A', 'P10DN5d', 'P10DN56'],
#              271: ['P10CvKk'],
#              272: ['RuHF04', 'gM9b002'],
#              273: ['P10CvLM', 'P10CvMc', 'RuHF03', 'YQA7C80'],
#              274: ['P10CvNK'],
#              275: ['G003418', 'gtM0007', 'gtM0008'],
#              276: ['P10CWAU', 'YQA7661', 'P10DN5b', 'P10DN4R'],
#              277: ['P10CvL6', 'YQA7693'],
#              278: ['P10DHoM', 'P10DHqa', 'P10CvNt', 'P10DN4U', 'P10CvMQ'],
#              279: ['P10CvMw', 'P10CvMJ', 'P10Do76'],
#              280: ['RuTE0J', 'P10CvL7', 'RuTE0I', 'RuHK08'],
#              281: ['RuU10E',
#               'RuTD02',
#               'RuU109',
#               'G003419',
#               'P10CvMo',
#               'P10CvNB'],
#              282: ['RuU10F', 'RuU10C', 'P10CvJw'],
#              283: ['P10DN5R', 'P10DN4z', 'P10DN5q', 'P10DN5t', 'P10DN5W'],
#              284: ['RuU10L',
#               'RuU10M',
#               'gtM0002',
#               'P10DHqo',
#               'RuTD07',
#               'RuU10H',
#               'RuU10O',
#               'P10DHpG',
#               'gM9a002',
#               'P10DN4A',
#               'P10DN5a',
#               'P10DHpo',
#               'P10DN59',
#               'P10DHpn',
#               'P10DHqO',
#               'gtM0001',
#               'P10DN4Y',
#               'RuU10I'],
#              285: ['P10CvNk',
#               'P10DHpj',
#               'P10CvNW',
#               'gMO8001',
#               'P10DN4K',
#               'RuU103',
#               'P10DN4J',
#               'P10CvL2',
#               'RuU106',
#               'P10DHpU',
#               'P10CvNu',
#               'P10DHpA',
#               'P10CvNa',
#               'gtM0005',
#               'P10DHq7',
#               'P10DHoN',
#               'RuU105',
#               'P10DHpD',
#               'P10CvNj',
#               'P10DHqw',
#               'P10CvLs',
#               'G003413',
#               'P10CvJX',
#               'P10DHqj',
#               'P10CWAY',
#               'P10DHpp',
#               'YQA761A',
#               'P10DHqt',
#               'P10DN5o',
#               'RuU10P',
#               'P10DHqq',
#               'P10CvLI',
#               'P10DHoj',
#               'P10CvN7',
#               'P10DHpk',
#               'P10CvNZ',
#               'P10DHp9',
#               'P10DN5y',
#               'P10DN5F',
#               'P10DN5i',
#               'P10DN4H',
#               'P10DN4E',
#               'P10CvNS',
#               'P10CvNs',
#               'P10CvM0',
#               'RuTD06',
#               'P10CvLl',
#               'P10DN5g',
#               'gtM0004',
#               'P10DHqe',
#               'P10DHqz',
#               'P10CvNl',
#               'P10DHoU',
#               'P10CvM3',
#               'P10DHqI',
#               'P10CvJI',
#               'P10DHq1',
#               'P10DN5M',
#               'RuU10N',
#               'P10DHpr',
#               'gtM0003',
#               'P10DHqs',
#               'P10DHpl',
#               'P10DHpX',
#               'RuU10A',
#               'P10CvJf',
#               'YQA7662'],
#              286: ['P10DHqc',
#               'P10DN5u',
#               'P10DN4M',
#               'P10DN5T',
#               'P10DN50',
#               'YQA768A',
#               'P10DHqu',
#               'P10DHol',
#               'YQA766D',
#               'P10CvMP',
#               'P10DHoW',
#               'P10DHqf'],
#              287: ['P10DHpw'],
#              288: ['P10DHoD'],
#              289: ['P10CvKd'],
#              290: ['RuU107'],
#              291: ['P10CvL5',
#               'YQA7692',
#               'P10CvKe',
#               'P10CvM2',
#               'P10CvLv',
#               'P10Ds3x'],
#              292: ['P10CvLr', 'P10CvKY', 'YQA7C7E'],
#              293: ['P10CvNA',
#               'P10CvNQ',
#               'P10CvK8',
#               'YQA7C5C',
#               'P10CvMX',
#               'YQA7C77',
#               'P10CvO4',
#               'YQA7CB4',
#               'P10CvN2',
#               'gMO8005',
#               'P10CvJV',
#               'P10CvMz',
#               'P10CqS5',
#               'YQA7CCA',
#               'P10CvJC',
#               'P10CqSq',
#               'P10CvJE',
#               'P10CvMY',
#               'P10CvNo',
#               'P10CvLG',
#               'P10CvMa',
#               'X51548',
#               'P10CvJR',
#               'gMO8006',
#               'P10CvLg',
#               'P10CvM6',
#               'YQA7C76',
#               'YQA7CB2',
#               'P10CvMO',
#               'P10CvMT',
#               'YQA7C3E',
#               'P10CvO1',
#               'YQA7C60',
#               'YQA7C5B',
#               'YQA7CB5',
#               'P10CvN6',
#               'P10CvJv',
#               'P10CvLJ',
#               'P10CvL3',
#               'YQA7C75',
#               'gMO8004',
#               'YQA7C61',
#               'P10CvMZ',
#               'P10CqUl',
#               'YQA7CB3',
#               'P10CqTM',
#               'P10CvKW'],
#              294: ['P10CvNw'],
#              295: ['P10CvLP'],
#              296: ['P10DHqb', 'P10CvMr'],
#              297: ['P10CvNc',
#               'YQA7C39',
#               'P10CvK2',
#               'P10CvLB',
#               'gMO8008',
#               'P10CvLE',
#               'P10CvLY',
#               'YQA7CB1',
#               'P10CvNC',
#               'P10CvJZ'],
#              298: ['P10CvN8', 'P10CqPZ', 'YQA7C59', 'Rv0C06'],
#              299: ['P10CvJM', 'P10CvMC'],
#              300: ['Rv9C00',
#               'P10CvNi',
#               'P10CvMW',
#               'P10CvL4',
#               'P10CvLp',
#               'YQA7C91',
#               'P10CvNh',
#               'P10CvNR',
#               'P10CvMm',
#               'P10CvNe',
#               'YQA7C8E',
#               'P10CvNb',
#               'YQA7C7D',
#               'YQC111C',
#               'RuTE0L',
#               'YQA7C73',
#               'RuHF07'],
#              301: ['P10CvO6', 'P10CvM8', 'RuHF05', 'P10CvLT'],
#              302: ['P10CvLL'],
#              303: ['P10CvNJ'],
#              304: ['P10CvLn', 'YQA7CA2'],
#              305: ['YQA767E', 'P10CvMu'],
#              306: ['P10CvL0',
#               'P10CvMb',
#               'P10CvLq',
#               'YRA8A4C',
#               'gtM0009',
#               'P10CvLy',
#               'P10CvMf',
#               'YQA7695',
#               'YQA7696',
#               'YRA8A4E',
#               'P10CvO3',
#               'YQA767F'],
#              307: ['P10CvLj', 'YQA7CA1'],
#              308: ['YRA8A50', 'YRA8A4F', 'P10CvM9'],
#              309: ['P10CvMi'],
#              310: ['P10CvK5', 'YQA7C7C'],
#              311: ['P10CvLV', 'YQA7C2C'],
#              312: ['P10CvMv',
#               'P10CvLQ',
#               'YQA7C8F',
#               'YQA7CA0',
#               'P10CvN9',
#               'P10CvK3',
#               'YQA7C7A',
#               'P10CvNy',
#               'YQA7C9F',
#               'YQA7C5E',
#               'P10CvLf',
#               'P10CvLO',
#               'P10CvMh',
#               'P10CvLW',
#               'P10CvMk',
#               'P10CvKZ',
#               'P10CvNf',
#               'YQA7CB6',
#               'P10CvMD',
#               'P10CvMp',
#               'YQA7CB0',
#               'YQA7C7F',
#               'YQA7C7B',
#               'X51547',
#               'P10CvK1',
#               'YQA7C9E'],
#              313: ['P10CvJr'],
#              314: ['P10CvNG'],
#              315: ['P10Ds37',
#               'P10Ds36',
#               'P10CvJQ',
#               'P10CvLb',
#               'crip001',
#               'YQA7C2B',
#               'P10CvKx',
#               'YQA7C2D',
#               'P10CvJq',
#               'P10Ds3C',
#               'P10CvLd',
#               'crit001',
#               'YQA7C38',
#               'criu786',
#               'P10Ds2R'],
#              316: ['P10CvL8'],
#              317: ['P10CqQ3',
#               'YQA7C3C',
#               'P10CvLF',
#               'YQA7C3A',
#               'YRAB78D',
#               'P10CvLm'],
#              318: ['gMO8007'],
#              319: ['YQA75EF'],
#              320: ['YQA75FC'],
#              321: ['P10CvJn'],
#              322: ['YQA7CC6'],
#              323: ['YQA75DE'],
#              324: ['P10CvMB'],
#              325: ['P10CqSf'],
#              326: ['P10CqUi'],
#              327: ['P10DHon'],
#              328: ['P10CvNF'],
#              329: ['P10DHpS'],
#              330: ['P10CWBm'],
#              331: ['P10CvK0'],
#              332: ['P10CWBo'],
#              333: ['P10CvLC'],
#              334: ['P10DN4B'],
#              335: ['YQA7C74'],
#              336: ['P10CWAQ'],
#              337: ['P10DHp2'],
#              338: ['P10DN4D', 'P10DHq0', 'P10DN51'],
#              339: ['P10DHpF'],
#              340: ['P10DHom', 'P10DHp5'],
#              341: ['RuU30B'],
#              342: ['P10CWzu', 'P10DHoB'],
#              343: ['P10DHoC', 'P10DHqK'],
#              344: ['P10DN4x'],
#              345: ['P10CvJW', 'RuU209', 'P10CvNv', 'P10CWC1', 'P10DHoK'],
#              346: ['P10DHpe', 'P10DHql'],
#              347: ['P10DHoy', 'P10DHpP'],
#              348: ['P10DHqE', 'P10DHoT', 'A103Hgh'],
#              349: ['P10CWAy'],
#              350: ['P10DHog'],
#              351: ['P10DHpH',
#               'P10DHqG',
#               'P10DN4P',
#               'P10DHqJ',
#               'P10CvKy',
#               'P10DHoZ'],
#              352: ['P10DHqF'],
#              353: ['P10DHoY'],
#              354: ['P10DHof'],
#              355: ['P10CvLi'],
#              356: ['P10DHqN'],
#              357: ['P10DHqh'],
#              358: ['P10CvN1'],
#              359: ['P10CvJL'],
#              360: ['P10CqRS'],
#              361: ['X51549'],
#              362: ['P10CvNz'],
#              363: ['P10Ds4K'],
#              364: ['P10CvJl'],
#              365: ['P10Ds38', 'YSAE271'],
#              366: ['P10CvKD'],
#              367: ['YSAE25B'],
#              368: ['YQA760A',
#               'YQA76A2',
#               'P10Ds3c',
#               'YQA767C',
#               'P10CvKU',
#               'YRA8A4B'],
#              369: ['P10DwK8'],
#              370: ['P10Ds4p'],
#              371: ['A1049x9'],
#              372: ['P10CqUD'],
#              373: ['P10CvJH'],
#              374: ['A103jBd'],
#              375: ['YQA75E1', 'gM99001', 'YSAE270', 'P10Ds4A'],
#              376: ['P10Ds2Z', 'YQA75ED', 'P10Ds33', 'YQA75DD'],
#              377: ['YQA75E2'],
#              378: ['P10CvJk'],
#              379: ['P10CWUY'],
#              380: ['P10CWVa'],
#              381: ['YQA7C79'],
#              382: ['P10CvJP'],
#              383: ['P10CvKg', 'P10CvKC'],
#              384: ['YQA7608',
#               'A103Hgw',
#               'P10CvKz',
#               'gM92001',
#               'RuHH03',
#               'P10CvKj'],
#              385: ['YQA7609'],
#              386: ['P10CWVh'],
#              387: ['YSAE282'],
#              388: ['YQA7C2A'],
#              389: ['YSAE26C'],
#              390: ['P10CvKA'],
#              391: ['P10CWUT'],
#              392: ['YQA7624'],
#              393: ['P10CvJh'],
#              394: ['P10CvKV'],
#              395: ['YSAE263'],
#              396: ['P10DHk2'],
#              397: ['P10CWV1'],
#              398: ['YQA75CA'],
#              399: ['P10CWCg'],
#              400: ['P10CWzJ'],
#              401: ['P10CvME'],
#              402: ['P10CvLU'],
#              403: ['P10CWVq'],
#              404: ['RuU30A'],
#              405: ['P10DHop'],
#              406: ['P10CvKE'],
#              407: ['P10CqQb'],
#              408: ['P10DHpd', 'P10DHqB', 'P10CWAT'],
#              409: ['P10DHpy'],
#              410: ['P10DHoO'],
#              411: ['P10CvJY'],
#              412: ['P10CvKt'],
#              413: ['YQA7100'],
#              414: ['P10CqPN'],
#              415: ['P10CvKs'],
#              416: ['P10DHod'],
#              417: ['P10CqPA'],
#              418: ['P10CvJo'],
#              419: ['P10CqPK'],
#              420: ['P10CqQ5'],
#              421: ['YSB3C22'],
#              422: ['P10CWzq'],
#              423: ['P10CvJg'],
#              424: ['P10CvKi'],
#              425: ['P10CYkp'],
#              426: ['A1047eS'],
#              427: ['A103BOp'],
#              428: ['A103nTh'],
#              429: ['P10Ci8Z'],
#              430: ['YQA7143'],
#              431: ['A103wzq'],
#              432: ['P10CIB5']})

# %%
# Arb set cutpoint based on the inconsistency metric 
cutoff = .5

########################################################

Z = linkage(numeric_vals, 'single')

# Cluster with a max d
max_d = 0.005
clusters_md = fcluster(Z, max_d, criterion='distance')
incon = inconsistent(Z,20)

print(incon[:5])
print(clusters_md[:25])
# Asteroid plot
fig=plt.figure(figsize=(18, 16))
plt.quiver(cxs, cys, mxs, mys, clusters_md, cmap='prism',scale=0.2, width=0.0005)
plt.xlim(-0.0, 0.3)
plt.ylim(-0.2, 0.1)
plt.xlabel('alpha')
plt.ylabel('beta')
plt.title('Asteroids 2.0')
# Out:
# [[  6.30874815e-05   0.00000000e+00   1.00000000e+00   0.00000000e+00]
#  [  1.20074368e-04   0.00000000e+00   1.00000000e+00   0.00000000e+00]
#  [  1.73729758e-04   0.00000000e+00   1.00000000e+00   0.00000000e+00]
#  [  1.76152826e-04   0.00000000e+00   1.00000000e+00   0.00000000e+00]
#  [  2.12454289e-04   0.00000000e+00   1.00000000e+00   0.00000000e+00]]
# [386  45   2 291 307  91 276  18 277 301 366 266 196 285 196 241 292 273
#  155 428 268 111 330 288 213]
